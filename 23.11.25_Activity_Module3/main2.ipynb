# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://query.data.world/s/marbvjrgtxbwyrv5ctr67y7i6eesam?dws=00000', low_memory=False)

# %%
df_copy = df.copy()

# %%
df_copy.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateAdded',
#        'dateUpdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageURLs', 'isbn', 'keys', 'manufacturer',
#        'manufacturerNumber', 'merchants', 'name', 'prices.amountMin',
#        'prices.amountMax', 'prices.availability', 'prices.color',
#        'prices.condition', 'prices.count', 'prices.currency',
#        'prices.dateAdded', 'prices.dateSeen', 'prices.flavor', 'prices.isSale',
#        'prices.merchant', 'prices.offer', 'prices.returnPolicy',
#        'prices.shipping', 'prices.size', 'prices.source', 'prices.sourceURLs',
#        'prices.warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceURLs', 'upc', 'websiteIDs', 'weight'],
#       dtype='object')

# %%
import json
import re

o = 0


for i in df_copy.features:
    print(o:=1+o,i)
    if i is not np.nan:    
        for x in json.loads(i):
            print(x['key'], x['value'][0])
# Out:
# 1 [{"key":"Season","value":["All-Season"]},{"key":"Material","value":["Synthetic"]},{"key":"Gender","value":["Women"]},{"key":"Shoe Size","value":["9"]},{"key":"Size","value":["9"]},{"key":"Color","value":["Blue"]},{"key":"Model","value":["Z130103201090"]},{"key":"Manufacturer Part Number","value":["Z130103201090"]},{"key":"Brand","value":["Zoot"]},{"key":"Age Group","value":["Adult"]}]
# Season All-Season
# Material Synthetic
# Gender Women
# Shoe Size 9
# Size 9
# Color Blue
# Model Z130103201090
# Manufacturer Part Number Z130103201090
# Brand Zoot
# Age Group Adult
# 2 [{"key":"Season","value":["All-Season"]},{"key":"Material","value":["Synthetic"]},{"key":"Gender","value":["Women"]},{"key":"Shoe Size","value":["9"]},{"key":"Size","value":["9"]},{"key":"Color","value":["Blue"]},{"key":"Model","value":["Z130103201090"]},{"key":"Manufacturer Part Number","value":["Z130103201090"]},{"key":"Brand","value":["Zoot"]},{"key":"Age Group","value":["Adult"]}]
# Season All-Season
# ...
