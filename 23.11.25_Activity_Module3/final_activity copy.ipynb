# %% [markdown]
# Import the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import json
import seaborn as sns



# %pip install currencyconverter
from currency_converter import CurrencyConverter
# Out:
# Requirement already satisfied: currencyconverter in c:\users\renzcute\appdata\local\programs\python\python310\lib\site-packages (0.17.13)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import the dataset

# %%
# df = pd.read_csv('https://query.data.world/s/4hitawaxckoxcgheh3mdxb5tafsmq6?dws=00000')
df = pd.read_csv('7210_1.csv', low_memory=False)

# %% [markdown]
# Copy the dataset for comparing the cleaned and non cleaned

# %%
df_cpy = df.copy()

# %% [markdown]
# Get the first 10 rows

# %%
df_cpy.head(10)
# Out:
#                      id asins             brand  \
# 0  AVpe__eOilAPnD_xSt-H   NaN            Novica
# 1  AVpe__eOilAPnD_xSt-H   NaN            Novica
# 2  AVpe__eOilAPnD_xSt-H   NaN            Novica
# 3  AVpe__eOilAPnD_xSt-H   NaN            Novica
# 4  AVpe__eOilAPnD_xSt-H   NaN            Novica
# 5  AVpe__eOilAPnD_xSt-H   NaN            Novica
# 6  AVpe__eOilAPnD_xSt-H   NaN            Novica
# 7  AVpe__JXilAPnD_xSt3F   NaN      Pedi Couture
# 8  AVpe_0mrilAPnD_xSqI7   NaN  ANNE KLEIN SPORT
# 9  AVpe_0mrilAPnD_xSqI7   NaN  ANNE KLEIN SPORT
#
#                                        categories  colors  count  \
# 0         Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
# 1         Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
# 2         Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
# 3         Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
# 4         Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
# 5         Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
# 6         Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
# 7  Clothing,Shoes,Women's Shoes,All Women's Shoes     NaN    NaN
# 8  Clothing,Shoes,Women's Shoes,All Women's Shoes     NaN    NaN
# 9  Clothing,Shoes,Women's Shoes,All Women's Shoes     NaN    NaN
#
#               dateAdded           dateUpdated  \
# 0  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 1  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 2  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 3  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 4  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 5  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 6  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 7  2016-11-10T09:13:23Z  2016-11-10T09:13:23Z
# 8  2016-08-02T08:29:11Z  2016-08-02T08:29:11Z
# 9  2016-08-02T08:29:11Z  2016-08-02T08:29:11Z
#
#                                         descriptions dimension  ...  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  ...
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  ...
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  ...
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  ...
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  ...
# 5  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  ...
# 6  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  ...
# 7  [{"dateSeen":["2016-11-10T09:13:23Z"],"sourceU...       NaN  ...
# 8  [{"dateSeen":["2016-08-02T08:29:11Z"],"sourceU...       NaN  ...
# 9  [{"dateSeen":["2016-08-02T08:29:11Z"],"sourceU...       NaN  ...
#
#                                                 skus  \
# 0  [{"sourceURLs":["https://www.overstock.com/Wor...
# 1  [{"sourceURLs":["https://www.overstock.com/Wor...
# 2  [{"sourceURLs":["https://www.overstock.com/Wor...
# 3  [{"sourceURLs":["https://www.overstock.com/Wor...
# 4  [{"sourceURLs":["https://www.overstock.com/Wor...
# 5  [{"sourceURLs":["https://www.overstock.com/Wor...
# 6  [{"sourceURLs":["https://www.overstock.com/Wor...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                           sourceURLs           upc vin  \
# 0  https://www.overstock.com/Worldstock-Fair-Trad...           NaN NaN
# 1  https://www.overstock.com/Worldstock-Fair-Trad...           NaN NaN
# 2  https://www.overstock.com/Worldstock-Fair-Trad...           NaN NaN
# 3  https://www.overstock.com/Worldstock-Fair-Trad...           NaN NaN
# 4  https://www.overstock.com/Worldstock-Fair-Trad...           NaN NaN
# 5  https://www.overstock.com/Worldstock-Fair-Trad...           NaN NaN
# 6  https://www.overstock.com/Worldstock-Fair-Trad...           NaN NaN
# 7  https://www.walmart.com/ip/PEDI-COUTURE-Women-...  8.396132e+10 NaN
# 8  http://www.walmart.com/ip/Anne-Klein-Sport-Per...           NaN NaN
# 9  http://www.walmart.com/ip/Anne-Klein-Sport-Per...           NaN NaN
#
#    websiteIDs weight Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51
# 0         NaN    NaN         NaN         NaN         NaN         NaN
# 1         NaN    NaN         NaN         NaN         NaN         NaN
# 2         NaN    NaN         NaN         NaN         NaN         NaN
# 3         NaN    NaN         NaN         NaN         NaN         NaN
# 4         NaN    NaN         NaN         NaN         NaN         NaN
# 5         NaN    NaN         NaN         NaN         NaN         NaN
# 6         NaN    NaN         NaN         NaN         NaN         NaN
# 7         NaN    NaN         NaN         NaN         NaN         NaN
# 8         NaN    NaN         NaN         NaN         NaN         NaN
# 9         NaN    NaN         NaN         NaN         NaN         NaN
#
# [10 rows x 52 columns]

# %% [markdown]
# Get the columns

# %%
df_cpy.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateAdded',
#        'dateUpdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageURLs', 'isbn', 'keys', 'manufacturer',
#        'manufacturerNumber', 'merchants', 'name', 'prices.amountMin',
#        'prices.amountMax', 'prices.availability', 'prices.color',
#        'prices.condition', 'prices.count', 'prices.currency',
#        'prices.dateAdded', 'prices.dateSeen', 'prices.flavor', 'prices.isSale',
#        'prices.merchant', 'prices.offer', 'prices.returnPolicy',
#        'prices.shipping', 'prices.size', 'prices.source', 'prices.sourceURLs',
#        'prices.warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceURLs', 'upc', 'vin', 'websiteIDs', 'weight', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51'],
#       dtype='object')

# %% [markdown]
# Get the info

# %%
df_cpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33801 entries, 0 to 33800
# Data columns (total 52 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   33801 non-null  object
#  1   asins                2422 non-null   object
#  2   brand                32817 non-null  object
#  3   categories           33801 non-null  object
#  4   colors               19844 non-null  object
#  5   count                0 non-null      float64
#  6   dateAdded            33801 non-null  object
#  7   dateUpdated          33801 non-null  object
#  8   descriptions         28425 non-null  object
#  9   dimension            1177 non-null   object
#  10  ean                  9778 non-null   float64
#  11  features             27181 non-null  object
#  12  flavors              0 non-null      float64
#  13  imageURLs            22309 non-null  object
#  14  isbn                 0 non-null      float64
#  15  keys                 33801 non-null  object
#  16  manufacturer         9279 non-null   object
#  17  manufacturerNumber   31434 non-null  object
#  18  merchants            15382 non-null  object
#  19  name                 33801 non-null  object
#  20  prices.amountMin     33801 non-null  float64
#  21  prices.amountMax     33801 non-null  float64
#  22  prices.availability  307 non-null    object
#  23  prices.color         17421 non-null  object
#  24  prices.condition     12015 non-null  object
#  25  prices.count         0 non-null      float64
#  26  prices.currency      33801 non-null  object
#  27  prices.dateAdded     33801 non-null  object
#  28  prices.dateSeen      33801 non-null  object
#  29  prices.flavor        0 non-null      float64
#  30  prices.isSale        33801 non-null  bool
#  31  prices.merchant      29926 non-null  object
#  32  prices.offer         6798 non-null   object
#  33  prices.returnPolicy  1374 non-null   object
#  34  prices.shipping      3948 non-null   object
#  35  prices.size          15391 non-null  object
#  36  prices.source        0 non-null      float64
#  37  prices.sourceURLs    33801 non-null  object
#  38  prices.warranty      0 non-null      float64
#  39  quantities           18490 non-null  object
#  40  reviews              4188 non-null   object
#  41  sizes                8602 non-null   object
#  42  skus                 22135 non-null  object
#  43  sourceURLs           33801 non-null  object
#  44  upc                  10724 non-null  float64
#  45  vin                  0 non-null      float64
#  46  websiteIDs           0 non-null      float64
#  47  weight               1263 non-null   object
#  48  Unnamed: 48          0 non-null      float64
#  49  Unnamed: 49          0 non-null      float64
#  50  Unnamed: 50          0 non-null      float64
#  51  Unnamed: 51          1 non-null      object
# dtypes: bool(1), float64(16), object(35)
# memory usage: 13.2+ MB

# %% [markdown]
# Describe all the columns

# %%
df_cpy.describe(include='all')
# Out:
#                           id  \
# count                  33801
# unique                  9996
# top     AVpfiLB71cnluZ0-mdRy
# freq                      79
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
#
#                                                     asins               brand  \
# count                                                2422               32817
# unique                                               1245                1360
# top     B002MUU6JG,B017MXDUZY,B002MUSAQW,B002MUSAQC,B0...  Journee Collection
# freq                                                   57                1401
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#                                             categories colors  count  \
# count                                            33801  19844    0.0
# unique                                             894   2065    NaN
# top     Clothing,Shoes,Women's Shoes,All Women's Shoes  Black    NaN
# freq                                              3156   2928    NaN
# mean                                               NaN    NaN    NaN
# std                                                NaN    NaN    NaN
# min                                                NaN    NaN    NaN
# 25%                                                NaN    NaN    NaN
# 50%                                                NaN    NaN    NaN
# 75%                                                NaN    NaN    NaN
# max                                                NaN    NaN    NaN
#
#                    dateAdded           dateUpdated  \
# count                  33801                 33801
# unique                  7006                  6506
# top     2017-03-28T11:43:08Z  2017-03-28T11:42:28Z
# freq                     253                   415
# mean                     NaN                   NaN
# std                      NaN                   NaN
# min                      NaN                   NaN
# 25%                      NaN                   NaN
# 50%                      NaN                   NaN
# 75%                      NaN                   NaN
# max                      NaN                   NaN
#
#                                              descriptions  \
# count                                               28425
# unique                                               7186
# top     [{"dateSeen":["2017-03-25T09:34:20.165Z"],"sou...
# freq                                                   67
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        dimension  ...  \
# count                       1177  ...
# unique                       100  ...
# top     6.0 in x 6.0 in x 1.0 in  ...
# freq                         238  ...
# mean                         NaN  ...
# std                          NaN  ...
# min                          NaN  ...
# 25%                          NaN  ...
# 50%                          NaN  ...
# 75%                          NaN  ...
# max                          NaN  ...
#
#                                                      skus  \
# count                                               22135
# unique                                               3808
# top     [{"sourceURLs":["http://www.ralphlauren.com/pr...
# freq                                                   79
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                sourceURLs           upc  vin  \
# count                                               33801  1.072400e+04  0.0
# unique                                               9993           NaN  NaN
# top     http://www.ralphlauren.com/product/index.jsp?p...           NaN  NaN
# freq                                                   79           NaN  NaN
# mean                                                  NaN  6.808845e+11  NaN
# std                                                   NaN  2.836908e+11  NaN
# min                                                   NaN  4.151870e+05  NaN
# 25%                                                   NaN  6.410790e+11  NaN
# 50%                                                   NaN  8.026160e+11  NaN
# 75%                                                   NaN  8.865210e+11  NaN
# max                                                   NaN  9.105300e+11  NaN
#
#         websiteIDs weight Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51
# count          0.0   1263         0.0         0.0         0.0           1
# unique         NaN     69         NaN         NaN         NaN           1
# top            NaN  499 g         NaN         NaN         NaN         9 g
# freq           NaN    559         NaN         NaN         NaN           1
# mean           NaN    NaN         NaN         NaN         NaN         NaN
# std            NaN    NaN         NaN         NaN         NaN         NaN
# min            NaN    NaN         NaN         NaN         NaN         NaN
# 25%            NaN    NaN         NaN         NaN         NaN         NaN
# 50%            NaN    NaN         NaN         NaN         NaN         NaN
# 75%            NaN    NaN         NaN         NaN         NaN         NaN
# max            NaN    NaN         NaN         NaN         NaN         NaN
#
# [11 rows x 52 columns]

# %% [markdown]
# Get all the missing values

# %%
df_cpy.isna().sum()
# Out:
# id                         0
# asins                  31379
# brand                    984
# categories                 0
# colors                 13957
# count                  33801
# dateAdded                  0
# dateUpdated                0
# descriptions            5376
# dimension              32624
# ean                    24023
# features                6620
# flavors                33801
# imageURLs              11492
# isbn                   33801
# keys                       0
# manufacturer           24522
# manufacturerNumber      2367
# merchants              18419
# name                       0
# prices.amountMin           0
# prices.amountMax           0
# prices.availability    33494
# prices.color           16380
# prices.condition       21786
# prices.count           33801
# prices.currency            0
# prices.dateAdded           0
# prices.dateSeen            0
# prices.flavor          33801
# prices.isSale              0
# prices.merchant         3875
# prices.offer           27003
# prices.returnPolicy    32427
# prices.shipping        29853
# prices.size            18410
# prices.source          33801
# prices.sourceURLs          0
# prices.warranty        33801
# quantities             15311
# reviews                29613
# sizes                  25199
# skus                   11666
# sourceURLs                 0
# upc                    23077
# vin                    33801
# websiteIDs             33801
# weight                 32538
# Unnamed: 48            33801
# Unnamed: 49            33801
# Unnamed: 50            33801
# Unnamed: 51            33800
# dtype: int64

# %% [markdown]
# As we can see, there are a lot of values to be removed, from here we will analyze all the columns with missing values.

# %% [markdown]
# First now check the data types of missing datas

# %%
df_cpy.loc[:, df_cpy.isna().any(axis=0)].dtypes
# Out:
# asins                   object
# brand                   object
# colors                  object
# count                  float64
# descriptions            object
# dimension               object
# ean                    float64
# features                object
# flavors                float64
# imageURLs               object
# isbn                   float64
# manufacturer            object
# manufacturerNumber      object
# merchants               object
# prices.availability     object
# prices.color            object
# prices.condition        object
# prices.count           float64
# prices.flavor          float64
# prices.merchant         object
# prices.offer            object
# prices.returnPolicy     object
# prices.shipping         object
# prices.size             object
# prices.source          float64
# prices.warranty        float64
# quantities              object
# reviews                 object
# sizes                   object
# skus                    object
# upc                    float64
# vin                    float64
# websiteIDs             float64
# weight                  object
# Unnamed: 48            float64
# Unnamed: 49            float64
# Unnamed: 50            float64
# Unnamed: 51             object
# dtype: object

# %% [markdown]
# Check all the columns that the entire rows are null

# %%
# get the columns that have all null values
(nulled_col := df_cpy.columns[df_cpy.isnull().all(axis=0)])
# Out:
# Index(['count', 'flavors', 'isbn', 'prices.count', 'prices.flavor',
#        'prices.source', 'prices.warranty', 'vin', 'websiteIDs', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50'],
#       dtype='object')

# %% [markdown]
# Remove the columns that the entire rows are null

# %%
# drop the null columns
df_cpy.drop(nulled_col, axis=1, inplace=True)
df_cpy.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'dateAdded',
#        'dateUpdated', 'descriptions', 'dimension', 'ean', 'features',
#        'imageURLs', 'keys', 'manufacturer', 'manufacturerNumber', 'merchants',
#        'name', 'prices.amountMin', 'prices.amountMax', 'prices.availability',
#        'prices.color', 'prices.condition', 'prices.currency',
#        'prices.dateAdded', 'prices.dateSeen', 'prices.isSale',
#        'prices.merchant', 'prices.offer', 'prices.returnPolicy',
#        'prices.shipping', 'prices.size', 'prices.sourceURLs', 'quantities',
#        'reviews', 'sizes', 'skus', 'sourceURLs', 'upc', 'weight',
#        'Unnamed: 51'],
#       dtype='object')

# %% [markdown]
# The <code>quantities</code> and <code>skus</code> column consists of json formatted strings, therefore we should get the 'value' key

# %%
# parse the json string to a python dictionary if it's not NaN
data_qty = df_cpy['quantities'].map(lambda x: json.loads(x) if pd.notnull(x) else x)

for i, v in data_qty.items():
    try:
        if len(v) > 1:
            # get the max value of the list
            v = max(v, key=lambda x: x['value'])['value']
        else:
            v = v[0]['value']
            
        # set the max value to the column
        df_cpy.loc[i, 'quantities'] = v
    except TypeError:
        df_cpy.loc[i, 'quantities'] = np.nan


# set the column to float
df_cpy['quantities'] = df_cpy['quantities'].astype(float)


def d(x):
    if pd.notnull(x):
        try:
            return json.loads(x)
        except json.JSONDecodeError:
            return x
    else:
        return x
    
data_rev = df_cpy['reviews'].map(d)

for i, v in data_rev.items():
    try:
        if len(v) > 1:
            # get the sum rating of the list
            v = sum([x['rating'] for x in v]) / len(v)
        else:
            v = v[0]['rating']
            
        # set the max value to the column
        df_cpy.loc[i, 'reviews'] = v
    except Exception as e:
        df_cpy.loc[i, 'reviews'] = np.nan


# set the column to float
df_cpy['reviews'] = df_cpy['reviews'].astype(float)

# %% [markdown]
# Get all the data numerical data types that has missing values

# %%
(nulled_num := df_cpy.loc[:, df_cpy.isna().any(axis=0)].select_dtypes(include=['float64', 'int64']).columns)
# Out:
# Index(['ean', 'quantities', 'reviews', 'upc'], dtype='object')

# %% [markdown]
# Handle all the missing data for numerical values by using the mean

# %%
df_cpy[nulled_num] = df_cpy[nulled_num].fillna(df_cpy[nulled_num].mean())
df_cpy[nulled_num].isna().sum() # check
# Out:
# ean           0
# quantities    0
# reviews       0
# upc           0
# dtype: int64

# %% [markdown]
# Check all the columns that was 50% of its data are missing

# %%
# Check all the columns that was 50% of its data are missing
(nulled_50 := 
 df_cpy.loc[
     :, 
     df_cpy.drop(
        df_cpy.dropna(
            axis=1, 
            thresh=df.shape[0] * 0.50, 
            inplace=False), 
        axis=1)
        .columns].columns)
# Out:
# Index(['asins', 'dimension', 'manufacturer', 'merchants',
#        'prices.availability', 'prices.condition', 'prices.offer',
#        'prices.returnPolicy', 'prices.shipping', 'prices.size', 'sizes',
#        'weight', 'Unnamed: 51'],
#       dtype='object')

# %% [markdown]
# Remove all the nulled columns and nulled 50% columns

# %%
df_cpy.drop(nulled_50, axis=1, inplace=True)
df_cpy.columns
# Out:
# Index(['id', 'brand', 'categories', 'colors', 'dateAdded', 'dateUpdated',
#        'descriptions', 'ean', 'features', 'imageURLs', 'keys',
#        'manufacturerNumber', 'name', 'prices.amountMin', 'prices.amountMax',
#        'prices.color', 'prices.currency', 'prices.dateAdded',
#        'prices.dateSeen', 'prices.isSale', 'prices.merchant',
#        'prices.sourceURLs', 'quantities', 'reviews', 'skus', 'sourceURLs',
#        'upc'],
#       dtype='object')

# %% [markdown]
# Check the nulls

# %%
df_cpy.isna().sum()
# Out:
# id                        0
# brand                   984
# categories                0
# colors                13957
# dateAdded                 0
# dateUpdated               0
# descriptions           5376
# ean                       0
# features               6620
# imageURLs             11492
# keys                      0
# manufacturerNumber     2367
# name                      0
# prices.amountMin          0
# prices.amountMax          0
# prices.color          16380
# prices.currency           0
# prices.dateAdded          0
# prices.dateSeen           0
# prices.isSale             0
# prices.merchant        3875
# prices.sourceURLs         0
# quantities                0
# reviews                   0
# skus                  11666
# sourceURLs                0
# upc                       0
# dtype: int64

# %% [markdown]
# The most important columns are the <code>brand</code>, <code>colors / prices.color</code>, <code>features</code>, and <code>description</code> so clean the rows that does not have values in this columns

# %%
# clean the rows that does not have values in columns colors, features and descriptions
prev_shape = df_cpy.shape[0]
df_cpy.dropna(subset=['features', 'descriptions', 'brand'], inplace=True)
print(df_cpy.columns)
# Out:
# Index(['id', 'brand', 'categories', 'colors', 'dateAdded', 'dateUpdated',
#        'descriptions', 'ean', 'features', 'imageURLs', 'keys',
#        'manufacturerNumber', 'name', 'prices.amountMin', 'prices.amountMax',
#        'prices.color', 'prices.currency', 'prices.dateAdded',
#        'prices.dateSeen', 'prices.isSale', 'prices.merchant',
#        'prices.sourceURLs', 'quantities', 'reviews', 'skus', 'sourceURLs',
#        'upc'],
#       dtype='object')

# %% [markdown]
# Special case for <code>colors</code> and <code>prices.color</code>

# %%
#combine the colors and prices.color

df_cpy['colors'] = df_cpy['colors'].fillna(df_cpy['prices.color'])

# drop the prices.color column
df_cpy.drop('prices.color', axis=1, inplace=True)

# drop the nulls on colors


print(f'{((prev_shape - df_cpy.shape[0]) / prev_shape)*100:.2f}% of the rows were dropped') 
print(df_cpy.columns)
# Out:
# 25.88% of the rows were dropped
# Index(['id', 'brand', 'categories', 'colors', 'dateAdded', 'dateUpdated',
#        'descriptions', 'ean', 'features', 'imageURLs', 'keys',
#        'manufacturerNumber', 'name', 'prices.amountMin', 'prices.amountMax',
#        'prices.currency', 'prices.dateAdded', 'prices.dateSeen',
#        'prices.isSale', 'prices.merchant', 'prices.sourceURLs', 'quantities',
#        'reviews', 'skus', 'sourceURLs', 'upc'],
#       dtype='object')

# %% [markdown]
# Remove the colors missing values

# %%
# remove colors rows with missing values
df_cpy.dropna(subset=['colors'], inplace=True)

# %%
df_cpy.isna().sum()
# Out:
# id                       0
# brand                    0
# categories               0
# colors                   0
# dateAdded                0
# dateUpdated              0
# descriptions             0
# ean                      0
# features                 0
# imageURLs             7068
# keys                     0
# manufacturerNumber     906
# name                     0
# prices.amountMin         0
# prices.amountMax         0
# prices.currency          0
# prices.dateAdded         0
# prices.dateSeen          0
# prices.isSale            0
# prices.merchant       1252
# prices.sourceURLs        0
# quantities               0
# reviews                  0
# skus                  4632
# sourceURLs               0
# upc                      0
# dtype: int64

# %% [markdown]
# Remove the remaining columns that has missing values

# %%
df_cpy.dropna(subset=['imageURLs', 'manufacturerNumber', 'prices.merchant', 'skus'], inplace=True)
df_cpy.isna().sum()
# Out:
# id                    0
# brand                 0
# categories            0
# colors                0
# dateAdded             0
# dateUpdated           0
# descriptions          0
# ean                   0
# features              0
# imageURLs             0
# keys                  0
# manufacturerNumber    0
# name                  0
# prices.amountMin      0
# prices.amountMax      0
# prices.currency       0
# prices.dateAdded      0
# prices.dateSeen       0
# prices.isSale         0
# prices.merchant       0
# prices.sourceURLs     0
# quantities            0
# reviews               0
# skus                  0
# sourceURLs            0
# upc                   0
# dtype: int64

# %% [markdown]
# Converts the date into epoch

# %%
#convert date to epoch
for feature in  ['dateAdded', 'dateUpdated', 'prices.dateAdded', 'prices.dateSeen']:
    df_cpy[feature] = pd.to_datetime(df_cpy[feature], errors='coerce')
    
    
    # if the value is not NaN, convert to epoch using lambda
    df_cpy[feature] = df_cpy[feature].map(lambda x: x if pd.isnull(x) else int(x.toordinal()))

# %% [markdown]
# Change the price currency into PHP

# %%
curs = {}
# get all the currency
for x in df_cpy['prices.currency'].unique():
    curs[x] = CurrencyConverter().convert(1, x, 'PHP')

# convert all the prices to PHP  
for x in curs.keys():
    df_cpy.loc[df_cpy['prices.currency'] == x, 'prices.amountMax'] = df_cpy.loc[df_cpy['prices.currency'] == x, 'prices.amountMax'].map(lambda y: y * curs[x])  
    df_cpy.loc[df_cpy['prices.currency'] == x, 'prices.amountMin'] = df_cpy.loc[df_cpy['prices.currency'] == x, 'prices.amountMin'].map(lambda y: y * curs[x])

# drop the prices.currency column (as all values will be converted to PHP)
df_cpy.drop('prices.currency', axis=1, inplace=True)

# %%
df_cpy['prices.amount'] = df_cpy[['prices.amountMax', 'prices.amountMin']].mean(axis=1)

# %%
df_cpy['colors'] = df_cpy['colors'].map(lambda x: x.lower())

for i, v in df_cpy['colors'].items():
    # non color values
    if 'women' in v:
        # remove the row
        df_cpy.drop(i, inplace=True)

# %%
df_cpy['colors'].unique()
# Out:
# array(['multicolor,multi', 'brown', 'white', 'cherrywhite', 'black',
#        'black,brown,grey,purple', 'black,white,black white', 'silver',
#        'grey,gray', 'black,black smooth leather', 'charcoal,chocolate',
#        'black,dark brown leather',
#        'black,blue,brown,taupe suede,tabacco brown',
#        'indianapolis colts,arizona cardinals,red,black,green,multi colored,houston texans,jacksonville jaguars,new york jets,multicolor,brown',
#        'brown,copper kettle', 'black,blue,brown,red', 'red',
#        'black suede,cuoio suede', 'beige,black,blue,cream',
#        'powder blue,black', 'brown,black suede',
#        'black leather,black points leather,cognac plisseelight leather,lake nubuck vienna,light red leather,mint leather,old brass,stone leather,taupe equipe leather,taupe equipe',
#        'whitegrey', 'light blue', 'sand tropic,beige', 'beige',
#        'gold,silver', 'berryredslime', 'cognac,cognac synthetic',
#        'beige,black,grey,red', 'black,brown,grey',
#        'black,white,white synthetic,mesh',
#        'red,whitehot pinkemerald,emeraldsilveremerald', 'pink',
#        'bright cherryleadgreen flash,multicolor', 'beige,white',
#        'black,grey', 'beige,black,red', 'black,brown,khaki,tan,cognac',
#        'black,brown',
#        'coral,pink,blue stripe,red stripe,mint,navy dot,blue',
#        'black,blackwhite', 'blue,pink,purple,red,tan',
#        'green,silver,white', 'blue', 'blackbright cherry suedetextile',
#        'black,brown,orange,pink,purple,red', 'black patent,silver',
#        'black,brown,grey,red,tan', 'beige,black,blue,beige black blue',
#        'stone,beige', 'yellow', 'black,brown,pink,white,beige',
#        'black,brown,tan', 'beige,black,blue,pink,yellow',
#        'beige,black,orange,beige black orange', 'stone,black,brown',
#        'grey,multi', 'black,pink', 'black nubuck,silk nubuck',
#        'black,brown,grey,black grey tan', 'black,brown,black brown',
#        'blue,navytan', 'beige,black,red,white',
#        'black,black multi leather', 'multi-colored', 'black,multi,red',
#        'grey', 'black,tan,taupe',
#        'black wool,beige wool,navy wool,green wool', 'nude',
#        'black,purple,white,black purple white', 'black,aquarius',
#        'black,pink,tan,white', 'dark brown', 'multicolor',
#        'whitechrome silverryka pin,gray', 'beige multi',
#        'black,red,white,black red white', 'greysteel blue rubbermesh',
#        'black,white', 'black,brown,grey,pink,beige,white', 'steel shine',
#        'greenwhite,gray', 'green,pink,purple,white', 'dazzling blueblack',
#        'black,purple,red,tan', 'beige,black,yellow',
#        'beige,black,brown,black brown tan',
#        'madera perforated suede,moonlight perforated suede',
#        'natural,chambray',
#        'sand nubuck leather,mesh fabric,silverwash,black tumbled leather,distressed nubuck',
#        'black,blue,ivory,pink,purple,red,silver', 'black,black quilted',
#        'cognac suede', 'black,multi,pink,white',
#        'orange,bright crimsondeep garnetwht,red', 'blue,yellow',
#        'black,blue,pink', 'beige,ntrlblcdblc', 'silver,pewter', 'tan',
#        'viper', 'purplewhite graphic,purple', 'green', 'pink,blue pink',
#        'inox grid fabric', 'black,gold,pink,red,white',
#        'blush n lace,tan  pink',
#        'black,blue,brown,green,red,dark green tan,brown tan,wine tan',
#        'bronze leatherblack patent',
#        'black,brown,tan,black brown tan,blk microfiber,tan microfiber,brown microfiber,multicolor',
#        'true red', 'black,gold,silver',
#        'black,brown,grey,red,tan,taupe,wine', 'black,red',
#        'taupe leather',
#        'red,white,vvd purplewhiteblkhypr orng,hypr orng,vvd purple,blk',
#        'orchid,silver,pewter,atlantic,poppy red,chocolate',
#        'brown croc patent,black croc patent', 'bone leather',
#        'bordeaux synthetic,bronze synthetic,navy synthetic',
#        'black,camel', 'black,brown,grey,red,white',
#        'black,brown,tan,black brown tan', 'gold,silver metallic',
#        'beige,blue,chocolate,port,black,purple,chestnut,feather,navy,sangria,dolphinblue,sand',
#        'bone', 'blue nubuck,metallic smooth',
#        'red,lightningwhiteturquoise', 'cognac,brown', 'black,otter,brown',
#        'black,blue,white,cheetah,pink', 'navy', 'pinkgrey stripe',
#        'black,blue,gold,red', 'regatta,sand', 'pink ribbon',
#        'pink,yellow', 'black,black leather,muskat,muskat leather',
#        'black,brown,khaki,camel', 'brown,expresso',
#        'beige,black,white,nude', 'white,champagne', 'black,bitter root',
#        'tan,black', 'black,white,nude,grey,red',
#        'beige,black,purple,beige black purple', 'black,tan,white',
#        'brown,white', 'red matte', 'stromboli synthetic',
#        'black,brown,grey,off-white,red,beige', 'orange',
#        'tan,blue,white,black polyurethane,black,beige,new navy polyurethane,tobacco polyurethane,beige polyurethane,brown,tan polyurethane',
#        'blue,black,cheetah,pink,blackcheetah',
#        'beige,black,blue,red,tan,white,cognac,natural', 'tan,champagne',
#        'beige,black,grey', 'blue,multi', 'black,onyxpurplemint',
#        'platino,silver', 'black,black calf', 'black,green,pink,white',
#        'blackbright cherry suedetextile,blue', 'black,red,tan,white',
#        'black patent', 'black,tan,black tan', 'winter white',
#        'multicolor,camel', 'coral,bark', 'black,blue,brown,purple',
#        'black deertanblack', 'black,tan', 'beige,black',
#        'black,army green,atmosphere,dark indigo,deep red,moonstone,n,a',
#        'blush,brown,brown rept,burgundy rept,light pink,pink,snake',
#        'black,natural', 'navy glitter',
#        'black,blue,white,black blue white', 'navy,print', 'grey,drkshdw',
#        'silver,silverturquoiselime punch',
#        'black tumbled,brown patent croco,black,tan tumbled,navy tumbled,brown tumbled,black patent croco,cranberry tumbled',
#        'cognac', 'black,grey,red', 'aruba bluedeep peacock',
#        'black,multi,tan,camel,flower',
#        'brown,bronze leather,pewter leather',
#        'black leather,salmon leather,white leather', 'navy veg calf',
#        'coralgrey', 'off-white', 'blue,blue spruce',
#        'black,grey,pink,purple', 'blue,nbl bluenvywht',
#        'red,university redbrght crmsnblk', 'persimmon',
#        'brown,gold,grey,white', 'brown,tanbeigetaupe suede',
#        'black linensuede trim',
#        'green,multi,glamour bone,glamour gold,glamour black,glamour pewter,metallic multi',
#        'black,blue,tan', 'black coral',
#        'tan,bone canvas,blue striped canvas,tan striped canvas,navy canvas',
#        'brown,grey,silver,tan', 'pink,white,blackpurple', 'white,honey',
#        'powder blue,natural', 'black,black patent',
#        'pink,pink blastblkelctrc grnwhite',
#        'white,white box,black,black box', 'multi', 'black,multi,tan',
#        'clear', 'chocolate,black,chestnut,gray', 'burgundy,black,nude',
#        'white,whiteblackwhite', 'whiteblue,white,gray',
#        'black,brown,red,tan',
#        'purple,gold,green,blue,silver stretch pu,white stretch patent,yellow stretch patent,black,black stretch pat,black-patent,lime stretch patent,orange str pat,pink,purple stretch pat,red,red stretch patent,white,white stretch pu',
#        'bronze,black', 'beige,purple', 'beige,black,brown,tan',
#        'black,truffle taupe', 'blackpink zing', 'gold,white',
#        'off-white,beige,brown', 'black,tan,taupe,whiskey', 'beige,mint',
#        'black,blue,grey,tan', 'brown,multi,colorful',
#        'black,brown,green,multi colored,red', 'beige,linen',
#        'grey,ocgwhtmpt', 'silver metallic',
#        'black metallic,bronze multi,white combo', 'dk browngreen,brown',
#        'black,silver,black silver,gold', 'blackblue', 'silver,champagne',
#        'beige,black,blue,red,white,mint,coral,navy', 'black,purple',
#        'black,tan,chestnut', 'fango leather', 'black,grey,tan',
#        'blue,herwhtlml', 'cream synthetic,black synthetic',
#        'black,silver,black silver', 'pink,purple,white',
#        'black,black softy patent', 'black,green,tan,olive',
#        'black,brown,camel,grey', 'black,black blue,gold', 'suede',
#        'pink,purple,pink purple', 'green,beach glassdiva pinkmint',
#        'beige,khaki,multi', 'brown,yellow,brown yellow', 'silver shimmer',
#        'pink,black', 'cordovan', 'platinum',
#        'black,brown,grey,pink,beige,tan', 'black,dark greywhiteblack',
#        'black,brown,grey,black brown grey',
#        'metallic,gold,silver metallic', 'black,multi,red,white',
#        'off-white,white', 'brown,black,chestnut', 'black,brown,grey,red',
#        'clear,red,clear red',
#        'black,orange,black multi orange,black orange,grey white herringbo',
#        'black,pink,white', 'green,turquoisesharp greenink', 'ivory',
#        'black g microfiber,doe g microfiber',
#        'white,whiteblue,whitebluer',
#        'black,green,pink,white,yellow,fuchsia,lime', 'black,blackpurple',
#        'blackblack,dark blue multi', 'maroon,grey,leopard',
#        'brown,truffle taupe', 'pinkpurple', 'black,red,tan,black red tan',
#        'brown,chestnut', 'purple,coffee',
#        'black,brown,grey,pink,black grey pink', 'brown,gold',
#        'purple,white', 'black,green,pink,red,white,blue,orange,yellow',
#        'purple,bleached lilacbleached lilac', 'black,grey,cognac',
#        'black,nude,grey,hot pink', 'blue,grey,red,blue grey red',
#        'red,tan,red tan', 'mocha soft kid', 'moccasin',
#        'black,blue,pink,purple,yellow', 'beige,black,tan,natural,whisky',
#        'black,grey,red,tan', 'black,brown,grey,red,beige',
#        'beige,black,green,grey,red,tan,charcoal,nude,taupe,olive,dusty pink,wine',
#        'no color', 'blue,tan', 'black,tan,white,chestnut',
#        'black,red,black red', 'black tumbled',
#        'black,blue,brown,grey,off-white,red,beige,white', 'gold', 'vinyl',
#        'black,brown,grey,tan', 'silverpink', 'classic navy leather',
#        'black,brown,red,black brown red', 'black,silver',
#        'black,brown,tan,cognac,taupe', 'black,beige,white',
#        'blue,gold,red', 'black,blue,gold,off-white,purple,red,yellow',
#        'blkwhite', 'black burnished calf', 'dark blue', 'lime green',
#        'off white', 'pure white', 'blue,vebwhtmed', 'stone,black,cognac',
#        'yellow,lt yllw', 'black,pink,silver,black pink silver',
#        'black,blackblack', 'gold,silver,gold silver', '9.5', '10', '5',
#        '5.5', '6', '6.5', '7', '7.5', '8', '8.5', '9', 'cherry red',
#        'grey,lightningice bluehot pink', 'white,beige,black',
#        'gold,ivory', 'beige,tan,black,taupe',
#        'grey,oatmealoatmealoatmealblack', 'blue,green',
#        'beige,black,brown,grey,black brown grey',
#        'black,brown,gold,pink,silver,beige,tan', 'pink,red,white,yellow',
#        'brown,grey', 'green,grey,purple,red,white', 'grey,pink,tan,white',
#        'coffee leather,black leather',
#        'black microfiber,denim microfiber,doe microfiber',
#        'pink,tpinkwhiteglg', 'black,gold,silver,black gold silver',
#        'violet', 'black,charcoal', 'blue,tan,blue tan',
#        'black,blue,brown,red,black blue red',
#        'black,brown,green,red,camel,khaki,olive,wine', 'white leather',
#        'beige,black,brown,grey,red,nude',
#        'tan,beige,charcoal leather,lobster leather,off white leather,tan leather',
#        'black,tan,nude,grey,taupe,peacock,rust',
#        'black,brown,grey,tan,black grey tan',
#        'lobster leather,off white leather',
#        'cordovan,black,black cabrio leather,blackcabrio',
#        'beige,black,brown,green,grey,red,nude,taupe,olive,wine',
#        'black,blue,black blue', 'ivory mesh lace',
#        'black,grey,off-white,pink', 'black,grey,tan,black grey tan',
#        'black,grey,khaki,olive,mustard', 'green,tan',
#        'beige,black,orange,white,natural', 'wheat',
#        'chestnut,chocolate brown,charcoal,burgundy',
#        'black,blackblack cool grey',
#        'black leather,bronze leather,pewter leather,silver leather',
#        'white satin', 'black,brown,black grey,grey', 'tide,other',
#        'black,brown,tan,camel', 'flight of fancy', 'black,pink,red,white',
#        'black micro', 'lavender', 'black,blackblackwhite',
#        'beige,black,tan', 'other', 'black,brown,grey,pink,tan',
#        'pink,grey', 'navy,black pink', 'black,blue,tan,yellow',
#        'bone leather,camel leather', 'beige,sparklelinen',
#        'black,red,tan', 'black,blue,tan,blue tan', 'brown,black',
#        'black,white,whitegrey,white  blue', 'blue,white,blue white',
#        'beige,white,beige white', 'black,brown,grey,pink,white',
#        'white,parchmentblackwhite', 'blue,pink,yellow,blue pink yellow',
#        'gold,white,black,berry,gold hatch,white paisley,blue,white flower burst,heart trellis,irises,tan leopard,pink,lime',
#        'off-white,white,off-white white', 'orange,red',
#        'beige,black,tan,white', 'blue,off-white', 'bronze,copper',
#        'nude patent leather', 'black,green,red,tan,olive,taupe,wine',
#        'black leather,natural leather', 'beige,black,blue,pink,white',
#        'black,pink,red', 'black lamy polyurethane,sand lamy polyurethane',
#        'blue,grey,tan', 'black,blue,pink,black blue pink',
#        'black,brown,white,yellow leather', 'black,grey,black grey',
#        'black,blue,brown,tan', 'white canvas,black canvas',
#        'black,black synthetic leather', 'black,brown,grey,pink',
#        'black,blue,grey,off-white,red', 'charcoal,black,navy,chocolate',
#        'blue,mint', 'black,blue,green,pink', 'wine,black,brown',
#        'tan,beige', 'beige,black,white', 'beige,black,pink',
#        'blue,mocha soft kid', 'grey,white,grey white',
#        'black,blue,grey,pink,red,silver', 'white,black online exclusive',
#        'black blue', 'pewter dots,black dots', 'black,taupe'],
#       dtype=object)

# %% [markdown]
# Normalize data

# %%
# normalize the data numerical only
df_cpy_norm = df_cpy.select_dtypes(include=['float64', 'int64']).apply(lambda x: x  / x.max())
df_cpy_norm = pd.concat([df_cpy_norm, df_cpy.select_dtypes(exclude=['float64', 'int64'])], axis=1)
df_cpy_norm.head()
# Out:
#     dateAdded  dateUpdated       ean  prices.amountMin  prices.amountMax  \
# 10   0.999804     0.999794  0.108457          0.019231          0.019231
# 11   0.999804     0.999794  0.108457          0.015385          0.015385
# 22   0.999058     0.999954  0.777857          0.101904          0.101904
# 23   0.999058     0.999954  0.777857          0.096135          0.096135
# 24   0.999058     0.999954  0.777857          0.088442          0.088442
#
#     prices.dateAdded  quantities   reviews       upc  prices.amount  ...  \
# 10          0.999794    0.492501  0.803593  0.108438       0.019231  ...
# 11          0.999794    0.492501  0.803593  0.108438       0.015385  ...
# 22          0.999237    1.000000  0.803593  0.765065       0.101904  ...
# 23          0.999237    1.000000  0.803593  0.765065       0.096135  ...
# 24          0.999989    1.000000  0.803593  0.765065       0.088442  ...
#
#                                             imageURLs  \
# 10  https://i5.walmartimages.com/asr/3990181c-1f37...
# 11  https://i5.walmartimages.com/asr/3990181c-1f37...
# 22  http://ak1.ostkcdn.com/images/products/6911382...
# 23  http://ak1.ostkcdn.com/images/products/6911382...
# 24  http://ak1.ostkcdn.com/images/products/6911382...
#
#                                                  keys manufacturerNumber  \
# 10  096506461056,0096506461056,sofcomfortwomenseve...              46105
# 11  096506461056,0096506461056,sofcomfortwomenseve...              46105
# 22            lugzwomenszenlo/14430937,lugz/wearls772         WEARLS-772
# 23            lugzwomenszenlo/14430937,lugz/wearls772         WEARLS-772
# 24            lugzwomenszenlo/14430937,lugz/wearls772         WEARLS-772
#
#                                                 name prices.dateSeen  \
# 10  Sof Comfort Women's Everyday Gel Insoles, 2-pair          736271
# 11  Sof Comfort Women's Everyday Gel Insoles, 2-pair          735905
# 22                       Lugz Women's Zen LO by Lugz          736065
# 23                       Lugz Women's Zen LO by Lugz          735861
# 24                       Lugz Women's Zen LO by Lugz             NaT
#
#    prices.isSale              prices.merchant  \
# 10         False  Walmart store - Walmart.com
# 11         False  Walmart store - Walmart.com
# 22         False                Overstock.com
# 23         False                Overstock.com
# 24         False                Overstock.com
#
#                                     prices.sourceURLs  \
# 10  https://www.walmart.com/ip/Sof-Comfort-Women-s...
# 11  http://www.walmart.com/ip/Sof-Comfort-Women-s-...
# 22  http://www.overstock.com/Clothing-Shoes/Lugz-W...
# 23  http://www.overstock.com/Clothing-Shoes/Lugz-W...
# 24  https://www.overstock.com/Clothing-Shoes/Lugz-...
#
#                                                  skus  \
# 10  [{"sourceURLs":["http://www.walmart.com/ip/Sof...
# 11  [{"sourceURLs":["http://www.walmart.com/ip/Sof...
# 22  [{"sourceURLs":["https://www.overstock.com/Clo...
# 23  [{"sourceURLs":["https://www.overstock.com/Clo...
# 24  [{"sourceURLs":["https://www.overstock.com/Clo...
#
#                                            sourceURLs
# 10  http://www.walmart.com/ip/Sof-Comfort-Women-s-...
# 11  http://www.walmart.com/ip/Sof-Comfort-Women-s-...
# 22  https://www.overstock.com/Clothing-Shoes/Lugz-...
# 23  https://www.overstock.com/Clothing-Shoes/Lugz-...
# 24  https://www.overstock.com/Clothing-Shoes/Lugz-...
#
# [5 rows x 26 columns]

# %% [markdown]
# <h2>Correlation</h2>

# %%
df_cpy_norm.corr(numeric_only=True)
# Out:
#                   dateAdded  dateUpdated       ean  prices.amountMin  \
# dateAdded          1.000000     0.124746 -0.218888          0.048661
# dateUpdated        0.124746     1.000000  0.016800          0.067817
# ean               -0.218888     0.016800  1.000000          0.159229
# prices.amountMin   0.048661     0.067817  0.159229          1.000000
# prices.amountMax   0.042074     0.072845  0.158002          0.986078
# prices.dateAdded   0.218296     0.209442 -0.025837         -0.041756
# quantities        -0.203556    -0.054505  0.040640          0.010277
# reviews            0.077479     0.055200  0.036790          0.005229
# upc               -0.211178     0.008084  0.952021          0.183334
# prices.amount      0.045507     0.070592  0.159167          0.996472
# prices.isSale      0.012688    -0.230962  0.005360         -0.059936
#
#                   prices.amountMax  prices.dateAdded  quantities   reviews  \
# dateAdded                 0.042074          0.218296   -0.203556  0.077479
# dateUpdated               0.072845          0.209442   -0.054505  0.055200
# ean                       0.158002         -0.025837    0.040640  0.036790
# prices.amountMin          0.986078         -0.041756    0.010277  0.005229
# prices.amountMax          1.000000         -0.059928    0.013807  0.006343
# prices.dateAdded         -0.059928          1.000000    0.067591  0.002334
# quantities                0.013807          0.067591    1.000000 -0.051946
# reviews                   0.006343          0.002334   -0.051946  1.000000
# upc                       0.181351         -0.025053    0.043223  0.038238
# prices.amount             0.996555         -0.051074    0.012095  0.005810
# prices.isSale            -0.057805         -0.173383   -0.032033  0.019234
#
#                        upc  prices.amount  prices.isSale
# dateAdded        -0.211178       0.045507       0.012688
# dateUpdated       0.008084       0.070592      -0.230962
# ean               0.952021       0.159167       0.005360
# prices.amountMin  0.183334       0.996472      -0.059936
# prices.amountMax  0.181351       0.996555      -0.057805
# prices.dateAdded -0.025053      -0.051074      -0.173383
# quantities        0.043223       0.012095      -0.032033
# reviews           0.038238       0.005810       0.019234
# upc               1.000000       0.182975       0.000507
# prices.amount     0.182975       1.000000      -0.059070
# prices.isSale     0.000507      -0.059070       1.000000

# %%
sns.regplot(x='prices.amountMax', y='prices.amountMin', data=df_cpy_norm)
plt.ylim(0,)
# Out:
# (0.0, 1.0499048076923077)

# %%
sns.regplot(x='prices.amountMin', y='prices.amount', data=df_cpy_norm)
plt.ylim(0,)
# Out:
# (0.0, 1.0501178554674533)

# %%
sns.regplot(x='prices.amountMax', y='prices.amount', data=df_cpy_norm)
plt.ylim(0,)
# Out:
# (0.0, 1.0499048076923077)

# %%
sns.regplot(x='quantities', y='prices.amount', data=df_cpy)
plt.ylim(0,)
# Out:
# (0.0, 30565.24671633399)

# %%
sns.regplot(x='prices.dateAdded', y='prices.amountMax', data=df_cpy)
plt.ylim(0,)
# Out:
# (0.0, 30565.24671633399)

# %%
sns.regplot(x='dateUpdated', y='prices.amount', data=df_cpy)
plt.ylim(0,)
# Out:
# (0.0, 30565.24671633399)

# %%
sns.regplot(x='dateAdded', y='prices.amount', data=df_cpy)
plt.ylim(0,)
# Out:
# (0.0, 30565.24671633399)

# %%
sns.regplot(x='prices.isSale', y='prices.amount', data=df_cpy)
plt.ylim(0,)
# Out:
# (0.0, 30565.24671633399)

# %%
sns.regplot(x='upc', y='prices.amount', data=df_cpy)
plt.ylim(0,)
# Out:
# (0.0, 30565.24671633399)

# %%
sns.regplot(x='ean', y='prices.amount', data=df_cpy)
plt.ylim(0,)
# Out:
# (0.0, 30565.24671633399)

# %%
sns.regplot(x='reviews', y='prices.amount', data=df_cpy)
plt.ylim(0,)
# Out:
# (0.0, 30565.24671633399)

# %%
df_cpy_norm.select_dtypes(exclude=['float64', 'int64']).columns
# Out:
# Index(['id', 'brand', 'categories', 'colors', 'descriptions', 'features',
#        'imageURLs', 'keys', 'manufacturerNumber', 'name', 'prices.dateSeen',
#        'prices.isSale', 'prices.merchant', 'prices.sourceURLs', 'skus',
#        'sourceURLs'],
#       dtype='object')

# %% [markdown]
# Top 20 brands

# %%
#show only top brands
sns.countplot(y='brand', data=df_cpy_norm, order=df_cpy_norm['brand'].value_counts().iloc[:20].index)
# Out:
# <AxesSubplot: xlabel='count', ylabel='brand'>

# %%
plt.xticks(rotation=90)
sns.boxplot(x='brand', y='prices.amount', data=df_cpy_norm, order=df_cpy_norm['brand'].value_counts().iloc[:30].index)
# Out:
# <AxesSubplot: xlabel='brand', ylabel='prices.amount'>

# %%
df_cpy_norm['brand'].unique()
# Out:
# array(['BEAUTIFEET', 'Lugz', 'Wild Diva', 'Dyeables', 'Reebok', 'Crocs',
#        'White Mountain', 'Journee Collection', 'Ellie', 'Nina',
#        'Gentle Souls', 'SoftWalk', 'SKECHERS', 'Ros Hommerson',
#        'Birkenstock', 'NFL', "Dr. Scholl's", 'Justin Boots', 'C Label',
#        'Bellini', 'Vaneli', 'Nature Breeze', 'Acorn', 'Blue Tongue',
#        'Minnetonka', 'Finn Comfort', 'Easy Spirit', 'Saucony',
#        'EasyComforts', 'Cushe', 'Fabulicious', 'Ann Creek', 'Rialto',
#        'Lane Boots', 'New Balance', 'SHELLYS LONDON', 'Asics',
#        'In-Sattva', 'Novica', 'Beacon Shoes', 'Refresh', 'Reneeze',
#        'Muk Luks', 'Unbranded', 'Converse', 'Leisureland', 'Adidas',
#        'FIC', 'Easy Street', 'Hailey Jeans Co.', 'Grasshoppers', 'Bamboo',
#        'Skechers', 'Beston', 'VIA PINKY', 'Mark and Maddux', 'USA Dawgs',
#        'Merrell', 'Faded Glory', 'Gabor', 'Sperry', 'Marc Fisher',
#        'Charades', 'Infinity', 'Fahrenheit', 'Nike',
#        'Flexus by Spring Step', 'Mia', 'Celeste', 'Academie Gear',
#        'DbDk Fashion', 'DF by Dearfoams', 'MUK LUKS', 'Diamondback',
#        'Devious', 'Ryka', 'Azura', 'Jambu', 'Gotta Flurt', 'ADI', 'PUMA',
#        'Pearl Izumi', 'SIDEKICK', 'Blue', 'Fergie Footwear', 'Op',
#        'Propet', 'Bordello', 'AdTec', 'Aerosoles', 'Diba True',
#        'A2 by Aerosoles', 'FERGIE', 'Vans', 'Carlos by Carlos Santana',
#        'Hades', 'Nine West', 'VANS', 'Durango', 'David Tate', 'FUNTASMA',
#        'Spenco', 'Qupid', 'Altra Footwear', 'Daniel Green', 'Minibasics',
#        'Ugg', 'La Plume', "L'Artiste by Spring Step", 'Pleaser',
#        'Ugg Australia', 'Cole Haan', 'Walking Cradles', 'Tredsafe',
#        'Danskin Now', 'Ilse Jacobsen', 'OM', 'Rieker-Antistress',
#        'Arider', 'Rainbow Sandals', 'Ara', 'BETANI', 'Adriana', 'C LABEL',
#        'Brinley Co.', 'Penny Loves Kenny', 'BearPaw', 'Fashion Focus',
#        'Trotters', 'Cape Robbin', 'Bella Vita', 'Earth Spirit', 'Dawgs',
#        'Ariat', 'S.C.', 'Karen Scott', 'Anne Klein', 'Touch Ups',
#        'BareTraps', 'Fila', 'CAPE ROBBIN', 'Helle Comfort', 'RocSoc',
#        'Klogs', 'GRASSHOPPERS', 'Gravity Defyer', 'Eastland', 'Forever',
#        'Dansko', 'DAWGS', 'Demonia', 'Steve Madden', 'Naturalizer',
#        'Under Armour', 'DimeCity', 'Footzyrolls', 'Burnetie',
#        'Charles by Charles David', 'Dromedaris', 'Elites',
#        'MUK LUKS A LA MODE', 'American Rag', 'Nomad', 'Fergalicious',
#        'Lamo', 'Icebug', 'Delicious', 'Diane von Furstenberg', 'FootJoy',
#        'Troentorp Bastad Clogs', 'OTBT', 'No Rules', 'Kelsi Dagger',
#        'Madeline', 'LILIANA', 'Indian Selections', 'Caparros',
#        'Toi et Moi', 'Enzo Angiolini', 'Toe Warmers', 'Clarks',
#        'Pink Paradox London', 'Staheekum', 'Old Friend', 'Pin Up', 'Ahnu',
#        'Avia', 'Apex', 'Brahma', 'Moksha Imports', 'NAYA', 'Lucky Brand',
#        'Keds', 'Big Buddha'], dtype=object)

# %%
df_grouped = df_cpy_norm[['brand', 'prices.amount']].groupby(['brand'])

e = {}
for b in df_cpy_norm['brand'].unique():
    e[b] = df_grouped.get_group(b)['prices.amount']

f_value, p_value = stats.f_oneway(*e.values())
print("ANOVA results: F=", f_value, ", P =", p_value)
# Out:
# ANOVA results: F= 141.5025745629576 , P = 0.0

# %% [markdown]
# Top 20 colors

# %%
#show only top colors
sns.countplot(y='colors', data=df_cpy_norm, order=df_cpy_norm['colors'].value_counts().iloc[:20].index)
# Out:
# <AxesSubplot: xlabel='count', ylabel='colors'>

# %%
plt.xticks(rotation=90)
sns.boxplot(x='colors', y='prices.amount', data=df_cpy_norm, order=df_cpy_norm['colors'].value_counts().iloc[:30].index)
# Out:
# <AxesSubplot: xlabel='colors', ylabel='prices.amount'>

# %% [markdown]
# IsSale

# %%
plt.xticks(rotation=90)
sns.boxplot(x='prices.isSale', y='prices.amount', data=df_cpy_norm)
# Out:
# <AxesSubplot: xlabel='prices.isSale', ylabel='prices.amount'>

# %%
df_cpy_norm.describe()
# Out:
#          dateAdded  dateUpdated          ean  prices.amountMin  \
# count  6948.000000  6948.000000  6948.000000       6948.000000
# mean      0.999404     0.999959     0.760117          0.113319
# std       0.000270     0.000049     0.160057          0.073600
# min       0.998463     0.999481     0.014527          0.001904
# 25%       0.999196     0.999959     0.777857          0.065303
# 50%       0.999345     0.999959     0.777857          0.094212
# 75%       0.999503     0.999989     0.777857          0.134519
# max       1.000000     1.000000     1.000000          1.000000
#
#        prices.amountMax  prices.dateAdded   quantities      reviews  \
# count       6948.000000       6948.000000  6948.000000  6948.000000
# mean           0.114025          0.999857     0.464094     0.803045
# std            0.074479          0.000259     0.352048     0.076312
# min            0.001904          0.998452     0.000000     0.200000
# 25%            0.065365          0.999908     0.100000     0.803593
# 50%            0.094644          0.999989     0.492501     0.803593
# 75%            0.134519          0.999989     0.850000     0.803593
# max            1.000000          1.000000     1.000000     1.000000
#
#                upc  prices.amount
# count  6948.000000    6948.000000
# mean      0.748466       0.113672
# std       0.166674       0.073781
# min       0.014525       0.001904
# 25%       0.765065       0.065365
# 50%       0.765065       0.094212
# 75%       0.765065       0.134519
# max       1.000000       1.000000

# %%
df_cpy_norm.describe(include=['object'])
# Out:
#                           id               brand  \
# count                   6948                6948
# unique                   791                 194
# top     AVpgdfn0LJeJML43ONQZ  Journee Collection
# freq                      60                 886
#
#                                           categories colors  \
# count                                           6948   6948
# unique                                           333    445
# top     Heels,Shoes,Women's Shoes,Journee Collection  black
# freq                                             400    876
#
#                                              descriptions  \
# count                                                6948
# unique                                                791
# top     [{"dateSeen":["2017-03-25T09:19:30.365Z"],"sou...
# freq                                                   60
#
#                                                  features  \
# count                                                6948
# unique                                                784
# top     [{"key":"Shoe Width","value":["Extra Wide, Med...
# freq                                                   60
#
#                                                 imageURLs  \
# count                                                6948
# unique                                                791
# top     http://ak1.ostkcdn.com/images/products/8858557...
# freq                                                   60
#
#                                                      keys manufacturerNumber  \
# count                                                6948               6948
# unique                                                791                780
# top     womenspropettourwalkerhookloopsportwhite/16086...       ESTRAVELTIME
# freq                                                   60                 87
#
#                                                      name  prices.dateSeen  \
# count                                                6948             6736
# unique                                                785              203
# top     Women's Easy Spirit Traveltime Light Natural/W...           736413
# freq                                                   87             4328
#
#        prices.merchant                                  prices.sourceURLs  \
# count             6948                                               6948
# unique              53                                               2143
# top      Overstock.com  https://www.overstock.com/Clothing-Shoes/Women...
# freq              6052                                                 59
#
#                                                      skus  \
# count                                                6948
# unique                                                791
# top     [{"sourceURLs":["https://www.overstock.com/Clo...
# freq                                                   60
#
#                                                sourceURLs
# count                                                6948
# unique                                                791
# top     https://www.overstock.com/Clothing-Shoes/Women...
# freq                                                   60

# %%
df_group = df_cpy[['brand', 'colors', 'prices.amount']]

group_test = df_group.groupby(['brand', 'colors'], as_index=False).mean(['prices.amount'])
group_test
# Out:
#                brand                             colors  prices.amount
# 0    A2 by Aerosoles                              black    3661.843809
# 1                ADI  black,brown,grey,pink,beige,white    1828.375903
# 2      Academie Gear              brown,grey,silver,tan    2860.326045
# 3      Academie Gear                              white    3526.519145
# 4              Acorn                              black    2501.762733
# ..               ...                                ...            ...
# 666        Wild Diva                          black,tan    1849.057169
# 667        Wild Diva                    black,tan,white    1937.654034
# 668        Wild Diva                              brown    2390.715730
# 669        Wild Diva                                red    1988.787349
# 670        Wild Diva                                tan    2401.026371
#
# [671 rows x 3 columns]

# %%
group_pivot = group_test.pivot(index='colors', columns='brand')
group_pivot
# Out:
#                    prices.amount                                             \
# brand            A2 by Aerosoles ADI Academie Gear Acorn AdTec       Adidas
# colors
# 10                           NaN NaN           NaN   NaN   NaN  3988.398538
# 5                            NaN NaN           NaN   NaN   NaN  3988.398538
# 5.5                          NaN NaN           NaN   NaN   NaN  3988.398538
# 6                            NaN NaN           NaN   NaN   NaN  3988.398538
# 6.5                          NaN NaN           NaN   NaN   NaN  3988.398538
# ...                          ...  ..           ...   ...   ...          ...
# whitegrey                    NaN NaN           NaN   NaN   NaN          NaN
# wine,black,brown             NaN NaN           NaN   NaN   NaN          NaN
# winter white                 NaN NaN           NaN   NaN   NaN          NaN
# yellow                       NaN NaN           NaN   NaN   NaN          NaN
# yellow,lt yllw               NaN NaN           NaN   NaN   NaN          NaN
#
#                                                         ...                \
# brand            Adriana Aerosoles Ahnu Altra Footwear  ... Ugg Australia
# colors                                                  ...
# 10                   NaN       NaN  NaN            NaN  ...           NaN
# 5                    NaN       NaN  NaN            NaN  ...           NaN
# 5.5                  NaN       NaN  NaN            NaN  ...           NaN
# 6                    NaN       NaN  NaN            NaN  ...           NaN
# 6.5                  NaN       NaN  NaN            NaN  ...           NaN
# ...                  ...       ...  ...            ...  ...           ...
# whitegrey            NaN       NaN  NaN            NaN  ...           NaN
# wine,black,brown     NaN       NaN  NaN            NaN  ...           NaN
# winter white         NaN       NaN  NaN            NaN  ...           NaN
# yellow               NaN       NaN  NaN            NaN  ...           NaN
# yellow,lt yllw       NaN       NaN  NaN            NaN  ...           NaN
#
#                                                                     \
# brand            Unbranded Under Armour VANS VIA PINKY Vaneli Vans
# colors
# 10                     NaN          NaN  NaN       NaN    NaN  NaN
# 5                      NaN          NaN  NaN       NaN    NaN  NaN
# 5.5                    NaN          NaN  NaN       NaN    NaN  NaN
# 6                      NaN          NaN  NaN       NaN    NaN  NaN
# 6.5                    NaN          NaN  NaN       NaN    NaN  NaN
# ...                    ...          ...  ...       ...    ...  ...
# whitegrey              NaN          NaN  NaN       NaN    NaN  NaN
# wine,black,brown       NaN          NaN  NaN       NaN    NaN  NaN
# winter white           NaN          NaN  NaN       NaN    NaN  NaN
# yellow                 NaN          NaN  NaN       NaN    NaN  NaN
# yellow,lt yllw         NaN          NaN  NaN       NaN    NaN  NaN
#
#
# brand            Walking Cradles White Mountain Wild Diva
# colors
# 10                           NaN            NaN       NaN
# 5                            NaN            NaN       NaN
# 5.5                          NaN            NaN       NaN
# 6                            NaN            NaN       NaN
# 6.5                          NaN            NaN       NaN
# ...                          ...            ...       ...
# whitegrey                    NaN            NaN       NaN
# wine,black,brown             NaN            NaN       NaN
# winter white                 NaN            NaN       NaN
# yellow                       NaN            NaN       NaN
# yellow,lt yllw               NaN            NaN       NaN
#
# [445 rows x 194 columns]

# %%
df_cpy_norm.columns
# Out:
# Index(['dateAdded', 'dateUpdated', 'ean', 'prices.amountMin',
#        'prices.amountMax', 'prices.dateAdded', 'quantities', 'reviews', 'upc',
#        'prices.amount', 'id', 'brand', 'categories', 'colors', 'descriptions',
#        'features', 'imageURLs', 'keys', 'manufacturerNumber', 'name',
#        'prices.dateSeen', 'prices.isSale', 'prices.merchant',
#        'prices.sourceURLs', 'skus', 'sourceURLs'],
#       dtype='object')

# %%
group_pivot_top30 = group_pivot.iloc[:, :30]

plt.pcolor(group_pivot_top30.fillna(0), cmap='RdBu')
plt.colorbar()
plt.plot()
# Out:
# []
